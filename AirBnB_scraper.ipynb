# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
Names = []
Names2 = []
Beds = []
Price = []
#Desc = []
#Reviews = []
#The following url is a search on airbnb canada for the city of windsor , it is the first page
url = "https://www.airbnb.ca/s/Windsor--Ontario--Canada/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&price_filter_input_type=0&price_filter_num_nights=5&query=Windsor%2C%20ON&place_id=ChIJa4hPtcEqO4gRUdz8J5XUbLY&date_picker_type=calendar&adults=1&source=structured_search_input_header&search_type=filter_change&checkin=2023-02-01&checkout=2023-02-02"
r = requests.get(url)
soup = BeautifulSoup(r.text, "lxml")

np = soup.find("a", class_ = "_1bfat5l").get("href")
cnp = "https://www.airbnb.ca"+str(np)


url = cnp
r = requests.get(url)
soup = BeautifulSoup(r.text, "lxml")

for i in range(1,14):

    names = soup.find_all("div" , class_ = "t1jojoys dir dir-ltr") #g1qv1ctd cb4nyux dir dir-ltr ; t1jojoys dir dir-ltr
    for i in names:
        n = i.text
        Names.append(n)
    names2 = soup.find_all("span" , class_ = "t6mzqp7 dir dir-ltr") 
    for i in names2:
        n = i.text
        Names2.append(n)
    beds =  soup.find_all("span" , class_ = " dir dir-ltr") 
    for i in desc2:
        n = i.text
        Beds.append(n)
    prices = soup.find_all("div" , class_ = "_tt122m")  #_1jo4hgw  ; _1y74zjx
    for i in prices:
        n = i.text
        Price.append(n)
    reviews = soup.find_all("span" , class_ = "t5eq1io r4a59j5 dir dir-ltr") 
    for i in reviews:
        n = i.text
        Reviews.append(n)
        
    df = pd.DataFrame({"Name":Names, "Name2":Names2,"Bedrooms":Beds,"Price":Price})#,"Reviews":Reviews
    df['Price'] = df['Price'].str.replace(' CAD total', '')
    df['Price'] = df['Price'].str.extract('(\d+)')
    df.to_csv("Airbnb_windsor.csv")

# %%
Names = []
Names2 = []
Beds = []
Price = []
#Desc = []
#Reviews = []
#The following url is a search on airbnb canada for the city of windsor , it is the first page
url = "https://www.airbnb.ca/s/Windsor--Ontario--Canada/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&price_filter_input_type=0&price_filter_num_nights=5&query=Windsor%2C%20ON&place_id=ChIJa4hPtcEqO4gRUdz8J5XUbLY&date_picker_type=calendar&adults=1&source=structured_search_input_header&search_type=filter_change&checkin=2023-02-01&checkout=2023-02-02"
r = requests.get(url)
soup = BeautifulSoup(r.text, "lxml")

np = soup.find("a", class_ = "_1bfat5l").get("href")
cnp = "https://www.airbnb.ca"+str(np)


url = cnp
r = requests.get(url)
soup = BeautifulSoup(r.text, "lxml")

for i in range(1,14):

    names = soup.find_all("div" , class_ = "t1jojoys dir dir-ltr") #g1qv1ctd cb4nyux dir dir-ltr ; t1jojoys dir dir-ltr
    for i in names:
        n = i.text
        Names.append(n)
    names2 = soup.find_all("span" , class_ = "t6mzqp7 dir dir-ltr") 
    for i in names2:
        n = i.text
        Names2.append(n)
    beds =  soup.find_all("span" , class_ = " dir dir-ltr") 
    for i in desc2:
        n = i.text
        Beds.append(n)
    prices = soup.find_all("div" , class_ = "_tt122m")  #_1jo4hgw  ; _1y74zjx
    for i in prices:
        n = i.text
        Price.append(n)
    reviews = soup.find_all("span" , class_ = "t5eq1io r4a59j5 dir dir-ltr") 
    for i in reviews:
        n = i.text
        Reviews.append(n)
    
    # Update the np variable with the next page's link
    np = soup.find_all("a", class_ = "_1bfat5l")[0].get("href")
    cnp = "https://www.airbnb.ca"+str(np)
    url = cnp
    r = requests.get(url)
    soup = BeautifulSoup(r.text, "lxml")
    
    df = pd.DataFrame({"Name":Names, "Name2":Names2,"Bedrooms":Beds,"Price":Price})#,"Reviews":Reviews
    df['Price'] = df['Price'].str.replace(' CAD total', '')
    df['Price'] = df['Price'].str.extract('(\d+)')
    df.to_csv("Airbnb_windsor.csv")

# %%
df
# Out:
#                                     Name  \
# 0                        Home in Windsor
# 1                 Guest suite in Windsor
# 2                     Cottage in Windsor
# 3                Private room in Windsor
# 4                Private room in Windsor
# ..                                   ...
# 229        Loft in Detroit, Michigan, US
# 230    Hotel room in Amherstburg, Canada
# 231      Private room in Windsor, Canada
# 232           Home in Troy, Michigan, US
# 233  Guesthouse in Detroit, Michigan, US
#
#                                                  Name2  \
# 0                       Year Round Hot Tub at The Gem!
# 1       Lakeshore Hidden Oasis (heated pool / jacuzzi)
# 2                   Serene, Cozy Cottage on the water.
# 3                     The fourth room is beautiful !!!
# 4    Cozy Private BR in a basement/queen bed+free W...
# ..                                                 ...
# 229  (Late checkout)DWTN Loft Blocks From Major Venues
# ...
